# %%
from selenium import webdriver 
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.service import Service
from urllib.parse import quote_plus
service = Service(executable_path="geckodriver.exe")
def init_driver(service):
    firefox_profile = webdriver.FirefoxProfile()
    firefox_profile.set_preference('dom.ipc.plugins.enabled.libflashplayer.so', False)  
    firefox_profile.set_preference("media.volume_scale", "0.0")  
    firefox_profile.set_preference("dom.webnotifications.enabled", False) 
    options = Options()
    options.profile = firefox_profile # to close the image loading
    return driver
driver = webdriver.Firefox(service=service)

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

username = quote_plus("youssefshadymatta")
password = quote_plus("y2172005s")

uri = f"mongodb+srv://{username}:{password}@cluster0.s8eo1.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# You successfully connected to MongoDB!

# %%
client.test
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02.s8eo1.mongodb.net:27017', 'cluster0-shard-00-01.s8eo1.mongodb.net:27017', 'cluster0-shard-00-00.s8eo1.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-atp5cg-shard-0', ssl=True, server_api=<pymongo.server_api.ServerApi object at 0x000001BD0A751CD0>), 'test')

# %%
jumiadb = client.jumia

# %%
driver.get("https://www.jumia.com.eg/")

# %%
from selenium.webdriver.common.by import By
click1 = driver.find_element(By.CSS_SELECTOR, ".cls")
click1.click()

# %%
click2 = driver.find_element(By.CSS_SELECTOR, "#fi-q")
click2.click()
click2.send_keys("smart watches")
click3 = driver.find_element(By.CSS_SELECTOR, "button.-mls")
click3.click()

# %%
click4 = driver.find_element(By.CSS_SELECTOR , "article.prd:nth-child(50) > a:nth-child(2) > div:nth-child(2) > h3:nth-child(1)").text
click4
# Out:
# 'Momax Mag.Link USB-C to USB-C'

# %%
titles = driver.find_elements(By.CSS_SELECTOR , "div.-paxs.row._no-g._4cl-3cm-shs article.prd._fb.col.c-prd")
len(titles)
# Out:
# 52

# %%
from selenium.webdriver.support.ui import WebDriverWait
products_list = []
for title in titles:
    product_title = ''
    product_title = title.find_element(By.CSS_SELECTOR , "div.info h3.name").text
    try:
        old_price = 0
        old_price = title.find_element(By.CSS_SELECTOR , "div.info div.s-prc-w div.old").text
    except:
        old_price = title.find_element(By.CSS_SELECTOR , "div.info div.prc").text

    try:
        product_discount = 0
        product_discount = title.find_element(By.CSS_SELECTOR , "div.info div.s-prc-w div.bdg._dsct._sm").text
    except:
        pass
    current_price = 0
    current_price = title.find_element(By.CSS_SELECTOR , "div.info div.prc").text

    product_list = {'product_title':product_title,
                       'current_price':current_price,
                       'old_price':old_price,
                        'discount':product_discount,
                       'published_at':False}
    products_list.append(product_list)
    _ = jumiadb.products.insert_one(product_list)  # insert documents (products) --> inside the jumia (collection)
print(products_list)
# Out:
# [{'product_title': 'Replacement Stainless Steel Band 20mm Bracelet For Samsung Galaxy Active 1/2 - 40/44mm - Silver', 'current_price': 'EGP 135.00', 'old_price': 'EGP 200.00', 'discount': '33%', 'published_at': False, '_id': ObjectId('674d5fb5a9477737a6c09d20')}, {'product_title': 'Huawei GT2 Pro Nano Ceramic Full Screen Protector - Black', 'current_price': 'EGP 95.00', 'old_price': 'EGP 200.00', 'discount': '53%', 'published_at': False, '_id': ObjectId('674d5fb5a9477737a6c09d21')}, {'product_title': 'Honor Band 6 Watch Full Screen Protector Film Not Glass - Transparent/Black', 'current_price': 'EGP 108.00', 'old_price': 'EGP 150.00', 'discount': '28%', 'published_at': False, '_id': ObjectId('674d5fb5a9477737a6c09d22')}, {'product_title': 'Replacement Band For Apple Watch Series 7 45mm - Black/White', 'current_price': 'EGP 112.00', 'old_price': 'EGP 200.00', 'discount': '44%', 'published_at': False, '_id': ObjectId('674d5fb5a9477737a6c09d23')}, {'product_title': 'Honor Watch ES, Huaw
# ...

# %%
DEHtfdrjngtfxdjygtxhdh
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 hamada <br> hamada
#
# NameError: name 'hamada' is not defined

# %%
products_title = []
products_cprice = []
products_oprice = []
products_dprice = []
for title in titles:
    product_title = ''
    product_title = title.find_element(By.CSS_SELECTOR , "div.info h3.name").text
    try:
        old_price = 0
        old_price = title.find_element(By.CSS_SELECTOR , "div.info div.s-prc-w div.old").text
    except:
        old_price = title.find_element(By.CSS_SELECTOR , "div.info div.prc").text

    try:
        product_discount = 0
        product_discount = title.find_element(By.CSS_SELECTOR , "div.info div.s-prc-w div.bdg._dsct._sm").text
    except:
        pass
    current_price = 0
    current_price = title.find_element(By.CSS_SELECTOR , "div.info div.prc").text
    products_title.append(product_title)
    products_cprice.append(current_price)
    products_oprice.append(old_price)
    products_dprice.append(product_discount)

# %%
import pandas as pd
df = pd.DataFrame(products_title , columns=["Product"])
df["Price"] = products_cprice
df["Old Price"] = products_oprice
df["Discount"] = products_dprice
df
# Out:
#                                               Product         Price  \
# 0   Replacement Stainless Steel Band 20mm Bracelet...    EGP 135.00
# 1   Huawei GT2 Pro Nano Ceramic Full Screen Protec...     EGP 95.00
# 2   Honor Band 6 Watch Full Screen Protector Film ...    EGP 108.00
# 3   Replacement Band For Apple Watch Series 7 45mm...    EGP 112.00
# 4   Honor Watch ES, Huawei Watch Fit Screen Protec...     EGP 95.00
# 5   Huawei Watch GT3 Pro Smart Watch 46mm 22mm Sil...    EGP 180.00
# 6   Honor Watch ES - 1.64-inch Screen Protector Fi...     EGP 95.00
# 7   Full Cover Case With Screen Protector FOR Huaw...    EGP 112.00
# 8   Apple Watch 45mm Series 7 Screen Protector - B...     EGP 95.00
# 9   Replacement Wrist Band Compatible With Xiaomi ...    EGP 130.00
# 10      Wristband Strap For Redmi Watch 2 Lite, Black    EGP 125.00
# 11  W&O X9 Ultra 2 (Super Amoled) Screen Smart Wat...    EGP 899.90
# 12           T1000 ULTRA Smart Watch SERIES 9 - Black    EGP 649.00
# ...
